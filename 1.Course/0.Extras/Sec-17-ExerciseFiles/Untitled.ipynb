# %%
import csv

# %%
file = open('find_link.csv')

# %%
file
# Out:
# <_io.TextIOWrapper name='find_link.csv' mode='r' encoding='cp1252'>

# %%
read_csv = csv.reader(file)

# %%
read_csv

# %%
type(read_csv)
# Out:
# _csv.reader

# %%
read_csv.line_num
# Out:
# 0

# %%
file.close()

# %%
lines = list(read_csv)

# %%
lines
# Out:
# [['h',
#   '53',
#   '24',
#   '46',
#   '4',
#   '11',
#   '3',
#   '35',
#   '17',
#   '52',
#   '9',
#   '60',
#   '26',
#   '60',
#   '72',
#   '39',
#   '11',
#   '80',
#   '86',
#   '66',
#   '59',
#   '9',
#   '41',
#   '33',
#   '11',
#   '42',
#   '69',
#   '74',
#   '91',
#   '61',
#   '5',
#   '69',
#   '17',
#   '17',
#   '78',
#   '6',
#   '51',
#   '54',
#   '54',
#   '94',
#   '47',
#   '37',
#   '0',
#   '16',
#   '71',
#   '6',
#   '83',
#   '7',
#   '6',
#   '38',
#   '61',
#   '18',
#   '68',
#   '15',
#   '2',
#   '81',
#   '49',
#   '5',
#   '17',
#   '21',
#   '36',
#   '63',
#   '38',
#   '24',
#   '3',
#   '99'],
#  ['85',
#   't',
#   '31',
#   '54',
#   '60',
#   '22',
#   '77',
#   '39',
#   '93',
#   '38',
#   '31',
#   '16',
#   '29',
#   '27',
#   '8',
#   '35',
#   '0',
#   '54',
#   '84',
#   '21',
#   '47',
#   '37',
#   '66',
#   '83',
#   '26',
#   '22',
#   '68',
#   '25',
#   '44',
#   '81',
#   '27',
#   '68',
#   '17',
#   '63',
#   '13',
# ...

# %%
import gdown
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-26-d8aea05c0030> in <module>
# ----> 1 import gdown
#
# ModuleNotFoundError: No module named 'gdown'

# %%
pip install gdown
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Created wheel for gdown: filename=gdown-3.11.1-py3-none-any.whl size=9662 sha256=937cd4c474391e8e77bdf5bbe8c9be28eb1253d51eae0bd885654945b1ba25a6
#   Stored in directory: c:\users\rragh\appdata\local\pip\cache\wheels\ac\0f\65\f8898ba51a103158b41f418d2a37cc928471624397da3af2f4
# Successfully built gdown
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import gdown

# %%
url = 'https://drive.google.com/open?id=1G6SEgg018UB4_4xsAJJ5TdzrhmXipr4Q'

# %%
gdown.download(url,output='some_file_name.pdf')
# Out:
# C:\Installs\General\Anaconda3\lib\site-packages\gdown\parse_url.py:31: UserWarning: You specified Google Drive Link but it is not the correct link to download the file. Maybe you should try: https://drive.google.com/uc?id=1G6SEgg018UB4_4xsAJJ5TdzrhmXipr4Q
#   url="https://drive.google.com/uc?id={}".format(file_id)
# Downloading...
# From: https://drive.google.com/open?id=1G6SEgg018UB4_4xsAJJ5TdzrhmXipr4Q
# To: C:\Users\rragh\OneDrive\Complete-Python-3-Bootcamp\1.Course\0.Extras\Sec-17-ExerciseFiles\some_file_name.pdf
# 71.8kB [00:00, 536kB/s]
# 'some_file_name.pdf'

# %%
md5 = '480b81c68d775af3f5c6d5e7ab437eb9'
gdown.cached_download(url, md5=md5, postprocess=gdown.extractall)
# Out:
# Computing MD5: C:\Users\rragh\.cache/gdown\https-COLON--SLASH--SLASH-drive.google.com-SLASH-open-QUESTION-id-EQUAL-1G6SEgg018UB4_4xsAJJ5TdzrhmXipr4Q
# MD5 matches: C:\Users\rragh\.cache/gdown\https-COLON--SLASH--SLASH-drive.google.com-SLASH-open-QUESTION-id-EQUAL-1G6SEgg018UB4_4xsAJJ5TdzrhmXipr4Q
# 'C:\\Users\\rragh\\.cache/gdown\\https-COLON--SLASH--SLASH-drive.google.com-SLASH-open-QUESTION-id-EQUAL-1G6SEgg018UB4_4xsAJJ5TdzrhmXipr4Q'

# %%
url = 'https://drive.google.com/uc?id=0B9P1L--7Wd2vNm9zMTJWOGxobkU'
output = '20150428_collected_images.tgz'
gdown.download(url, output, quiet=False)

md5 = 'fa837a88f0c40c513d975104edf3da17'
gdown.cached_download(url, output, md5=md5, postprocess=gdown.extractall)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=0B9P1L--7Wd2vNm9zMTJWOGxobkU
# To: C:\Users\rragh\OneDrive\Complete-Python-3-Bootcamp\1.Course\0.Extras\Sec-17-ExerciseFiles\20150428_collected_images.tgz
# 44.7MB [00:11, 3.90MB/s]
# Computing MD5: 20150428_collected_images.tgz
# MD5 matches: 20150428_collected_images.tgz
# '20150428_collected_images.tgz'

# %%
url = 'https://drive.google.com/open?id=1G6SEgg018UB4_4xsAJJ5TdzrhmXipr4Q'
output = 'some_file_name.pdf'
gdown.download(url, output, quiet=False)

md5 = 'd4f8b2fc4225b703a0a3b29f246dc6eb'
gdown.cached_download(url, output, md5=md5, postprocess=gdown.extractall)
# Out:
# Downloading...
# From: https://drive.google.com/open?id=1G6SEgg018UB4_4xsAJJ5TdzrhmXipr4Q
# To: C:\Users\rragh\OneDrive\Complete-Python-3-Bootcamp\1.Course\0.Extras\Sec-17-ExerciseFiles\some_file_name.pdf
# 71.8kB [00:00, 442kB/s]
# MD5 doesn't match:
# actual: 1756d7d82d0f562ffde878ff07c0d153
# expected: d4f8b2fc4225b703a0a3b29f246dc6eb
# Cached Downloading: some_file_name.pdf
# Computing MD5: some_file_name.pdf
# Downloading...
# From: https://drive.google.com/open?id=1G6SEgg018UB4_4xsAJJ5TdzrhmXipr4Q
# To: C:\Users\rragh\.cache\gdown\tmp0c8otpkf\dl
# 71.8kB [00:00, 440kB/s]
# Computing MD5: some_file_name.pdf
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-11-3423f15548cd> in <module>
#       4
#       5 md5 = 'd4f8b2fc4225b703a0a3b29f246dc6eb'
# ----> 6 gdown.cached_download(url, output, md5=md5, postprocess=gdown.extractall)
#
# ...
