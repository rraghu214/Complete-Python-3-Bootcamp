# %%
2+1
# Out:
# 3

# %%
2-1
# Out:
# 1

# %%
2*3
# Out:
# 6

# %%
2/3
# Out:
# 0.6666666666666666

# %%
7/4
# Out:
# 1.75

# %%
7 % 4
# Out:
# 3

# %%
50 % 5
# Out:
# 0

# %%
200 % 99
# Out:
# 2

# %%
23 % 2
# Out:
# 1

# %%
20 ** 3
# Out:
# 8000

# %%
0.1+0.2-0.3
# Out:
# 5.551115123125783e-17

# %%
0.1+0.2-0.3
# Out:
# 5.551115123125783e-17

# %%
round((0.1 + 0.2),3)
# Out:
# 0.3

# %%
1/10
# Out:
# 0.1

# %%
6**6
# Out:
# 46656

# %%
from math import *

# %%
def cube_root(n):
    return round(n**(1/3),2)

# %%
cube_root(8)
# Out:
# 2.0

# %%
cube_root(9)
# Out:
# 2.08

# %%
from math import sqrt,sin,cos,tan,log,exp

# %%
sqrt(16)
# Out:
# 4.0

# %%
sin(1)
# Out:
# 0.8414709848078965

# %%
cos(1)
# Out:
# 0.5403023058681398

# %%
tan(1)
# Out:
# 1.5574077246549023

# %%
log(1)
# Out:
# 0.0

# %%
exp(0)
# Out:
# 1.0

# %%
val = float(input())
# Out:
# 2.3

# %%
val
# Out:
# 2.3

# %%
a = {'1':'one','2':'two'}

a['1']
# Out:
# 'one'

# %%
def fun1():
    return '123'

def fun2(val):
    val()

val = input('Function: ')
fun2(val)
# Out:
# Function: fun1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-a06735502800> in <module>
#       6
#       7 val = input('Function: ')
# ----> 8 fun2(val)
#
# <ipython-input-28-a06735502800> in fun2(val)
#       3
#       4 def fun2(val):
# ----> 5     val()
#       6
#       7 val = input('Function: ')
#
# TypeError: 'str' object is not callable

# %%
ceil(3.499)
# Out:
# 4

# %%
nums = {1, 2, 3, 4, 5, 6}
nums = {0, 1, 2, 3} & nums
nums = filter(lambda x: x > 1, nums)
print(len(list(nums)))
# Out:
# 2

# %%
nums = {1, 2, 3, 4, 5, 6}
nums = {0, 1, 2, 3} & nums
print(nums)
# Out:
# {1, 2, 3}

# %%
a = {"apple", "banana", "cherry"}
b = {"apple", "banana", "berry","curry"}
print(a - b)
# Out:
# {'cherry'}

# %%
def power(x, y):
    if y == 0:
        print(f' If cond, x is {x}. y is {y}')
        return 1
    else:
        print(f'x is {x}. y is {y}')
        print(x * power(x, y-1))
        return x * power(x, y-1)

# %%
power(2,3)
# Out:
# x is 2. y is 3
# x is 2. y is 2
# x is 2. y is 1
#  If cond, x is 2. y is 0
# 2
#  If cond, x is 2. y is 0
# 4
# x is 2. y is 1
#  If cond, x is 2. y is 0
# 2
#  If cond, x is 2. y is 0
# 8
# x is 2. y is 2
# x is 2. y is 1
#  If cond, x is 2. y is 0
# 2
#  If cond, x is 2. y is 0
# 4
# x is 2. y is 1
#  If cond, x is 2. y is 0
# 2
#  If cond, x is 2. y is 0
# 8

# %%
from collections import Counter

x = [1,1,2,3,4,2,1,2,4,5,2]

Counter(x)
# Out:
# Counter({1: 3, 2: 4, 3: 1, 4: 2, 5: 1})

# %%
pip install covid
# Out:
# Collecting covid
#   Using cached https://files.pythonhosted.org/packages/33/e7/7f34e774dd6ac7362d607ad578d24a7df930740a2b4ba77f57e16f630787/covid-2.2.10.tar.gz
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: beautifulsoup4 in c:\installs\others\anaconda3\lib\site-packages (from covid) (4.8.0)
# Collecting pydantic (from covid)
#   Downloading https://files.pythonhosted.org/packages/8c/54/982f84b9ccec93f1e0defda2d7691d860b0deafee3ec25c17885a9004fcc/pydantic-1.5.1-cp37-cp37m-win_amd64.whl (1.7MB)
# Requirement already satisfied: requests in c:\installs\others\anaconda3\lib\site-packages (from covid) (2.22.0)
# Requirement already satisfied: soupsieve>=1.2 in c:\installs\others\anaconda3\lib\site-packages (from beautifulsoup4->covid) (1.9.3)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\installs\others\anaconda3\lib\site-packages (from requests->covid) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\installs\others\anaconda3\lib\site-packages (from requests->covid) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\installs\others\anaconda3\lib\site-packages (from requests->covid) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\installs\others\anaconda3\lib\site-packages (from requests->covid) (3.0.4)
# Building wheels for collected packages: covid
#   Building wheel for covid (PEP 517): started
#   Building wheel for covid (PEP 517): finished with status 'done'
#   Created wheel for covid: filename=covid-2.2.10-cp37-none-any.whl size=8454 sha256=bd7482e6b0579fa3058f50f62386f01d76c81f5b968304a38dde835573687385
#   Stored in directory: C:\Users\rragh\AppData\Local\pip\Cache\wheels\3d\e2\c7\3db2fa66456c45fa0eab57ae1ab92272a26f44e82e58af96dd
# Successfully built covid
# Installing collected packages: pydantic, covid
# Successfully installed covid-2.2.10 pydantic-1.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from covid import Covid

#covid = Covid()
covid = Covid(source="worldometers")
covid.get_data()
# Out:
# [{'country': 'North America',
#   'confirmed': 2229176,
#   'new_cases': 5160,
#   'deaths': 133972,
#   'recovered': 898723,
#   'active': 1196481,
#   'critical': 19520,
#   'new_deaths': 692,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'South America',
#   'confirmed': 1072792,
#   'new_cases': 484,
#   'deaths': 47463,
#   'recovered': 520953,
#   'active': 504376,
#   'critical': 11756,
#   'new_deaths': 12,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'Europe',
#   'confirmed': 2071611,
#   'new_cases': 9490,
#   'deaths': 178175,
#   'recovered': 1065767,
#   'active': 827669,
#   'critical': 7321,
#   'new_deaths': 216,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'Asia',
#   'confirmed': 1299214,
#   'new_cases': 7091,
#   'deaths': 33792,
#   'recovered': 786754,
#   'active': 478668,
#   'critical': 14574,
#   'new_deaths': 117,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'Africa',
#   'confirmed': 179337,
#   'new_cases': 0,
#   'deaths': 4942,
#   'recovered': 80324,
#   'active': 94071,
#   'critical': 443,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'Oceania',
#   'confirmed': 8865,
#   'new_cases': 4,
#   'deaths': 124,
#   'recovered': 8275,
#   'active': 466,
#   'critical': 2,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': '0',
#   'confirmed': 721,
#   'new_cases': 0,
#   'deaths': 15,
#   'recovered': 651,
#   'active': 55,
#   'critical': 4,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'World',
#   'confirmed': 6861716,
#   'new_cases': 22229,
#   'deaths': 398483,
#   'recovered': 3361447,
#   'active': 3101786,
#   'critical': 53620,
#   'new_deaths': 1037,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('880'),
#   'total_deaths_per_million': Decimal('51.1'),
#   'population': Decimal('0')},
#  {'country': 'USA',
#   'confirmed': 1965912,
#   'new_cases': 204,
#   'deaths': 111394,
#   'recovered': 738729,
#   'active': 1115789,
#   'critical': 17121,
#   'new_deaths': 4,
#   'total_tests': 20270325,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('5942'),
#   'total_deaths_per_million': Decimal('337'),
#   'population': Decimal('330869944')},
#  {'country': 'Brazil',
#   'confirmed': 646006,
#   'new_cases': 0,
#   'deaths': 35047,
#   'recovered': 302084,
#   'active': 308875,
#   'critical': 8318,
#   'new_deaths': 0,
#   'total_tests': 999836,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3041'),
#   'total_deaths_per_million': Decimal('165'),
#   'population': Decimal('212455128')},
#  {'country': 'Russia',
#   'confirmed': 458689,
#   'new_cases': 8855,
#   'deaths': 5725,
#   'recovered': 221388,
#   'active': 231576,
#   'critical': 2300,
#   'new_deaths': 197,
#   'total_tests': 12388968,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3143'),
#   'total_deaths_per_million': Decimal('39'),
#   'population': Decimal('145930359')},
#  {'country': 'Spain',
#   'confirmed': 288058,
#   'new_cases': 0,
#   'deaths': 27134,
#   'recovered': 0,
#   'active': 0,
#   'critical': 617,
#   'new_deaths': 0,
#   'total_tests': 4063843,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('6161'),
#   'total_deaths_per_million': Decimal('580'),
#   'population': Decimal('46753591')},
#  {'country': 'UK',
#   'confirmed': 283311,
#   'new_cases': 0,
#   'deaths': 40261,
#   'recovered': 0,
#   'active': 0,
#   'critical': 604,
#   'new_deaths': 0,
#   'total_tests': 5214277,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('4175'),
#   'total_deaths_per_million': Decimal('593'),
#   'population': Decimal('67861743')},
#  {'country': 'India',
#   'confirmed': 236954,
#   'new_cases': 770,
#   'deaths': 6649,
#   'recovered': 114073,
#   'active': 116232,
#   'critical': 8944,
#   'new_deaths': 0,
#   'total_tests': 4524317,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('172'),
#   'total_deaths_per_million': Decimal('5'),
#   'population': Decimal('1379048498')},
#  {'country': 'Italy',
#   'confirmed': 234531,
#   'new_cases': 0,
#   'deaths': 33774,
#   'recovered': 163781,
#   'active': 36976,
#   'critical': 316,
#   'new_deaths': 0,
#   'total_tests': 4114572,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3879'),
#   'total_deaths_per_million': Decimal('559'),
#   'population': Decimal('60467569')},
#  {'country': 'Peru',
#   'confirmed': 187400,
#   'new_cases': 0,
#   'deaths': 5162,
#   'recovered': 79214,
#   'active': 103024,
#   'critical': 1041,
#   'new_deaths': 0,
#   'total_tests': 1154468,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('5689'),
#   'total_deaths_per_million': Decimal('157'),
#   'population': Decimal('32938493')},
#  {'country': 'Germany',
#   'confirmed': 185414,
#   'new_cases': 0,
#   'deaths': 8763,
#   'recovered': 168900,
#   'active': 7751,
#   'critical': 595,
#   'new_deaths': 0,
#   'total_tests': 4348880,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2213'),
#   'total_deaths_per_million': Decimal('105'),
#   'population': Decimal('83765996')},
#  {'country': 'Turkey',
#   'confirmed': 168340,
#   'new_cases': 0,
#   'deaths': 4648,
#   'recovered': 133400,
#   'active': 30292,
#   'critical': 592,
#   'new_deaths': 0,
#   'total_tests': 2267412,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1998'),
#   'total_deaths_per_million': Decimal('55'),
#   'population': Decimal('84274682')},
#  {'country': 'Iran',
#   'confirmed': 167156,
#   'new_cases': 0,
#   'deaths': 8134,
#   'recovered': 129741,
#   'active': 29281,
#   'critical': 2573,
#   'new_deaths': 0,
#   'total_tests': 1040289,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1992'),
#   'total_deaths_per_million': Decimal('97'),
#   'population': Decimal('83915513')},
#  {'country': 'France',
#   'confirmed': 153055,
#   'new_cases': 0,
#   'deaths': 29111,
#   'recovered': 70504,
#   'active': 53440,
#   'critical': 1094,
#   'new_deaths': 0,
#   'total_tests': 1384633,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2345'),
#   'total_deaths_per_million': Decimal('446'),
#   'population': Decimal('65263909')},
#  {'country': 'Chile',
#   'confirmed': 122499,
#   'new_cases': 0,
#   'deaths': 1448,
#   'recovered': 95631,
#   'active': 25420,
#   'critical': 1521,
#   'new_deaths': 0,
#   'total_tests': 668556,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('6412'),
#   'total_deaths_per_million': Decimal('76'),
#   'population': Decimal('19104748')},
#  {'country': 'Mexico',
#   'confirmed': 110026,
#   'new_cases': 4346,
#   'deaths': 13170,
#   'recovered': 78590,
#   'active': 18266,
#   'critical': 378,
#   'new_deaths': 625,
#   'total_tests': 324897,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('854'),
#   'total_deaths_per_million': Decimal('102'),
#   'population': Decimal('128836832')},
#  {'country': 'Saudi Arabia',
#   'confirmed': 95748,
#   'new_cases': 0,
#   'deaths': 642,
#   'recovered': 70616,
#   'active': 24490,
#   'critical': 1321,
#   'new_deaths': 0,
#   'total_tests': 908972,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2753'),
#   'total_deaths_per_million': Decimal('18'),
#   'population': Decimal('34774012')},
#  {'country': 'Canada',
#   'confirmed': 94335,
#   'new_cases': 0,
#   'deaths': 7703,
#   'recovered': 52568,
#   'active': 34064,
#   'critical': 1738,
#   'new_deaths': 0,
#   'total_tests': 1830498,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2501'),
#   'total_deaths_per_million': Decimal('204'),
#   'population': Decimal('37719025')},
#  {'country': 'Pakistan',
#   'confirmed': 93983,
#   'new_cases': 4734,
#   'deaths': 1935,
#   'recovered': 32581,
#   'active': 59467,
#   'critical': 111,
#   'new_deaths': 97,
#   'total_tests': 660508,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('426'),
#   'total_deaths_per_million': Decimal('9'),
#   'population': Decimal('220568077')},
#  {'country': 'Qatar',
#   'confirmed': 65495,
#   'new_cases': 0,
#   'deaths': 49,
#   'recovered': 40935,
#   'active': 24511,
#   'critical': 238,
#   'new_deaths': 0,
#   'total_tests': 246362,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('23326'),
#   'total_deaths_per_million': Decimal('17'),
#   'population': Decimal('2807805')},
#  {'country': 'Bangladesh',
#   'confirmed': 60391,
#   'new_cases': 0,
#   'deaths': 811,
#   'recovered': 12804,
#   'active': 46776,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 372365,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('367'),
#   'total_deaths_per_million': Decimal('5'),
#   'population': Decimal('164573672')},
#  {'country': 'Belgium',
#   'confirmed': 58907,
#   'new_cases': 0,
#   'deaths': 9566,
#   'recovered': 16112,
#   'active': 33229,
#   'critical': 137,
#   'new_deaths': 0,
#   'total_tests': 912165,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('5084'),
#   'total_deaths_per_million': Decimal('826'),
#   'population': Decimal('11586214')},
#  {'country': 'Netherlands',
#   'confirmed': 47152,
#   'new_cases': 0,
#   'deaths': 6005,
#   'recovered': 0,
#   'active': 0,
#   'critical': 97,
#   'new_deaths': 0,
#   'total_tests': 388113,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2752'),
#   'total_deaths_per_million': Decimal('351'),
#   'population': Decimal('17132352')},
#  {'country': 'Belarus',
#   'confirmed': 46868,
#   'new_cases': 0,
#   'deaths': 259,
#   'recovered': 22066,
#   'active': 24543,
#   'critical': 92,
#   'new_deaths': 0,
#   'total_tests': 597013,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('4960'),
#   'total_deaths_per_million': Decimal('27'),
#   'population': Decimal('9449526')},
#  {'country': 'South Africa',
#   'confirmed': 43434,
#   'new_cases': 0,
#   'deaths': 908,
#   'recovered': 23088,
#   'active': 19438,
#   'critical': 208,
#   'new_deaths': 0,
#   'total_tests': 850871,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('733'),
#   'total_deaths_per_million': Decimal('15'),
#   'population': Decimal('59254905')},
#  {'country': 'Sweden',
#   'confirmed': 42939,
#   'new_cases': 0,
#   'deaths': 4639,
#   'recovered': 0,
#   'active': 0,
#   'critical': 265,
#   'new_deaths': 0,
#   'total_tests': 275500,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('4254'),
#   'total_deaths_per_million': Decimal('460'),
#   'population': Decimal('10094947')},
#  {'country': 'Ecuador',
#   'confirmed': 41575,
#   'new_cases': 0,
#   'deaths': 3534,
#   'recovered': 20568,
#   'active': 17473,
#   'critical': 252,
#   'new_deaths': 0,
#   'total_tests': 120845,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2359'),
#   'total_deaths_per_million': Decimal('201'),
#   'population': Decimal('17623415')},
#  {'country': 'UAE',
#   'confirmed': 37642,
#   'new_cases': 0,
#   'deaths': 274,
#   'recovered': 20337,
#   'active': 17031,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 2145493,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3809'),
#   'total_deaths_per_million': Decimal('28'),
#   'population': Decimal('9881840')},
#  {'country': 'Singapore',
#   'confirmed': 37183,
#   'new_cases': 0,
#   'deaths': 24,
#   'recovered': 24209,
#   'active': 12950,
#   'critical': 4,
#   'new_deaths': 0,
#   'total_tests': 408495,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('6359'),
#   'total_deaths_per_million': Decimal('4'),
#   'population': Decimal('5847148')},
#  {'country': 'Colombia',
#   'confirmed': 36635,
#   'new_cases': 0,
#   'deaths': 1145,
#   'recovered': 13638,
#   'active': 21852,
#   'critical': 335,
#   'new_deaths': 0,
#   'total_tests': 386938,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('721'),
#   'total_deaths_per_million': Decimal('23'),
#   'population': Decimal('50844444')},
#  {'country': 'Portugal',
#   'confirmed': 33969,
#   'new_cases': 0,
#   'deaths': 1465,
#   'recovered': 20526,
#   'active': 11978,
#   'critical': 58,
#   'new_deaths': 0,
#   'total_tests': 873998,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3331'),
#   'total_deaths_per_million': Decimal('144'),
#   'population': Decimal('10198608')},
#  {'country': 'Egypt',
#   'confirmed': 31115,
#   'new_cases': 0,
#   'deaths': 1166,
#   'recovered': 8158,
#   'active': 21791,
#   'critical': 41,
#   'new_deaths': 0,
#   'total_tests': 135000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('304'),
#   'total_deaths_per_million': Decimal('11'),
#   'population': Decimal('102189071')},
#  {'country': 'Switzerland',
#   'confirmed': 30936,
#   'new_cases': 0,
#   'deaths': 1921,
#   'recovered': 28600,
#   'active': 415,
#   'critical': 29,
#   'new_deaths': 0,
#   'total_tests': 415915,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3576'),
#   'total_deaths_per_million': Decimal('222'),
#   'population': Decimal('8650247')},
#  {'country': 'Kuwait',
#   'confirmed': 30644,
#   'new_cases': 0,
#   'deaths': 244,
#   'recovered': 18277,
#   'active': 12123,
#   'critical': 197,
#   'new_deaths': 0,
#   'total_tests': 308900,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('7183'),
#   'total_deaths_per_million': Decimal('57'),
#   'population': Decimal('4265955')},
#  {'country': 'Indonesia',
#   'confirmed': 29521,
#   'new_cases': 0,
#   'deaths': 1770,
#   'recovered': 9443,
#   'active': 18308,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 380973,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('108'),
#   'total_deaths_per_million': Decimal('6'),
#   'population': Decimal('273318704')},
#  {'country': 'Ukraine',
#   'confirmed': 26514,
#   'new_cases': 550,
#   'deaths': 777,
#   'recovered': 11812,
#   'active': 13925,
#   'critical': 301,
#   'new_deaths': 15,
#   'total_tests': 414542,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('606'),
#   'total_deaths_per_million': Decimal('18'),
#   'population': Decimal('43750132')},
#  {'country': 'Poland',
#   'confirmed': 25410,
#   'new_cases': 0,
#   'deaths': 1137,
#   'recovered': 12641,
#   'active': 11632,
#   'critical': 160,
#   'new_deaths': 0,
#   'total_tests': 1014937,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('671'),
#   'total_deaths_per_million': Decimal('30'),
#   'population': Decimal('37849296')},
#  {'country': 'Ireland',
#   'confirmed': 25163,
#   'new_cases': 0,
#   'deaths': 1670,
#   'recovered': 22698,
#   'active': 795,
#   'critical': 36,
#   'new_deaths': 0,
#   'total_tests': 348416,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('5100'),
#   'total_deaths_per_million': Decimal('338'),
#   'population': Decimal('4933861')},
#  {'country': 'Argentina',
#   'confirmed': 21037,
#   'new_cases': 0,
#   'deaths': 632,
#   'recovered': 6088,
#   'active': 14317,
#   'critical': 274,
#   'new_deaths': 0,
#   'total_tests': 183862,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('466'),
#   'total_deaths_per_million': Decimal('14'),
#   'population': Decimal('45166698')},
#  {'country': 'Philippines',
#   'confirmed': 20626,
#   'new_cases': 0,
#   'deaths': 987,
#   'recovered': 4330,
#   'active': 15309,
#   'critical': 82,
#   'new_deaths': 0,
#   'total_tests': 408945,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('188'),
#   'total_deaths_per_million': Decimal('9'),
#   'population': Decimal('109475626')},
#  {'country': 'Romania',
#   'confirmed': 20103,
#   'new_cases': 0,
#   'deaths': 1316,
#   'recovered': 14145,
#   'active': 4642,
#   'critical': 152,
#   'new_deaths': 0,
#   'total_tests': 484782,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1045'),
#   'total_deaths_per_million': Decimal('68'),
#   'population': Decimal('19245644')},
#  {'country': 'Afghanistan',
#   'confirmed': 19551,
#   'new_cases': 582,
#   'deaths': 320,
#   'recovered': 1820,
#   'active': 17411,
#   'critical': 19,
#   'new_deaths': 11,
#   'total_tests': 45900,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('503'),
#   'total_deaths_per_million': Decimal('8'),
#   'population': Decimal('38860571')},
#  {'country': 'Dominican Republic',
#   'confirmed': 18708,
#   'new_cases': 0,
#   'deaths': 525,
#   'recovered': 11736,
#   'active': 6447,
#   'critical': 110,
#   'new_deaths': 0,
#   'total_tests': 90141,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1726'),
#   'total_deaths_per_million': Decimal('48'),
#   'population': Decimal('10840235')},
#  {'country': 'Israel',
#   'confirmed': 17706,
#   'new_cases': 144,
#   'deaths': 292,
#   'recovered': 15042,
#   'active': 2372,
#   'critical': 29,
#   'new_deaths': 1,
#   'total_tests': 637863,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1925'),
#   'total_deaths_per_million': Decimal('32'),
#   'population': Decimal('9197590')},
#  {'country': 'Japan',
#   'confirmed': 17064,
#   'new_cases': 0,
#   'deaths': 907,
#   'recovered': 14972,
#   'active': 1185,
#   'critical': 98,
#   'new_deaths': 0,
#   'total_tests': 307462,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('135'),
#   'total_deaths_per_million': Decimal('7'),
#   'population': Decimal('126501158')},
#  {'country': 'Austria',
#   'confirmed': 16843,
#   'new_cases': 0,
#   'deaths': 672,
#   'recovered': 15742,
#   'active': 429,
#   'critical': 20,
#   'new_deaths': 0,
#   'total_tests': 485912,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1871'),
#   'total_deaths_per_million': Decimal('75'),
#   'population': Decimal('9002889')},
#  {'country': 'Panama',
#   'confirmed': 15463,
#   'new_cases': 0,
#   'deaths': 370,
#   'recovered': 9719,
#   'active': 5374,
#   'critical': 77,
#   'new_deaths': 0,
#   'total_tests': 72697,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3588'),
#   'total_deaths_per_million': Decimal('86'),
#   'population': Decimal('4309767')},
#  {'country': 'Oman',
#   'confirmed': 15086,
#   'new_cases': 0,
#   'deaths': 72,
#   'recovered': 3451,
#   'active': 11563,
#   'critical': 60,
#   'new_deaths': 0,
#   'total_tests': 102644,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2960'),
#   'total_deaths_per_million': Decimal('14'),
#   'population': Decimal('5096376')},
#  {'country': 'Bahrain',
#   'confirmed': 13835,
#   'new_cases': 0,
#   'deaths': 23,
#   'recovered': 8585,
#   'active': 5227,
#   'critical': 11,
#   'new_deaths': 1,
#   'total_tests': 354122,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('8155'),
#   'total_deaths_per_million': Decimal('14'),
#   'population': Decimal('1696592')},
#  {'country': 'Bolivia',
#   'confirmed': 12728,
#   'new_cases': 483,
#   'deaths': 427,
#   'recovered': 1739,
#   'active': 10562,
#   'critical': 3,
#   'new_deaths': 12,
#   'total_tests': 28239,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1091'),
#   'total_deaths_per_million': Decimal('37'),
#   'population': Decimal('11661480')},
#  {'country': 'Kazakhstan',
#   'confirmed': 12511,
#   'new_cases': 199,
#   'deaths': 52,
#   'recovered': 6903,
#   'active': 5556,
#   'critical': 62,
#   'new_deaths': 0,
#   'total_tests': 915904,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('667'),
#   'total_deaths_per_million': Decimal('3'),
#   'population': Decimal('18760630')},
#  {'country': 'Armenia',
#   'confirmed': 12364,
#   'new_cases': 547,
#   'deaths': 190,
#   'recovered': 3720,
#   'active': 8454,
#   'critical': 10,
#   'new_deaths': 7,
#   'total_tests': 66674,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('4173'),
#   'total_deaths_per_million': Decimal('64'),
#   'population': Decimal('2962876')},
#  {'country': 'Denmark',
#   'confirmed': 11875,
#   'new_cases': 0,
#   'deaths': 586,
#   'recovered': 10653,
#   'active': 636,
#   'critical': 17,
#   'new_deaths': 0,
#   'total_tests': 684557,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2051'),
#   'total_deaths_per_million': Decimal('101'),
#   'population': Decimal('5790832')},
#  {'country': 'Nigeria',
#   'confirmed': 11844,
#   'new_cases': 0,
#   'deaths': 333,
#   'recovered': 3696,
#   'active': 7815,
#   'critical': 7,
#   'new_deaths': 0,
#   'total_tests': 73064,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('58'),
#   'total_deaths_per_million': Decimal('2'),
#   'population': Decimal('205738192')},
#  {'country': 'S. Korea',
#   'confirmed': 11719,
#   'new_cases': 51,
#   'deaths': 273,
#   'recovered': 10531,
#   'active': 915,
#   'critical': 15,
#   'new_deaths': 0,
#   'total_tests': 1005305,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('229'),
#   'total_deaths_per_million': Decimal('5'),
#   'population': Decimal('51266282')},
#  {'country': 'Serbia',
#   'confirmed': 11667,
#   'new_cases': 0,
#   'deaths': 247,
#   'recovered': 6931,
#   'active': 4489,
#   'critical': 12,
#   'new_deaths': 0,
#   'total_tests': 266061,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1335'),
#   'total_deaths_per_million': Decimal('28'),
#   'population': Decimal('8739599')},
#  {'country': 'Algeria',
#   'confirmed': 9935,
#   'new_cases': 0,
#   'deaths': 690,
#   'recovered': 6453,
#   'active': 2792,
#   'critical': 22,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('227'),
#   'total_deaths_per_million': Decimal('16'),
#   'population': Decimal('43791767')},
#  {'country': 'Iraq',
#   'confirmed': 9846,
#   'new_cases': 0,
#   'deaths': 285,
#   'recovered': 4573,
#   'active': 4988,
#   'critical': 63,
#   'new_deaths': 0,
#   'total_tests': 281901,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('245'),
#   'total_deaths_per_million': Decimal('7'),
#   'population': Decimal('40152757')},
#  {'country': 'Czechia',
#   'confirmed': 9529,
#   'new_cases': 0,
#   'deaths': 327,
#   'recovered': 6881,
#   'active': 2321,
#   'critical': 12,
#   'new_deaths': 0,
#   'total_tests': 464499,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('890'),
#   'total_deaths_per_million': Decimal('31'),
#   'population': Decimal('10707664')},
#  {'country': 'Moldova',
#   'confirmed': 9247,
#   'new_cases': 0,
#   'deaths': 323,
#   'recovered': 5240,
#   'active': 3684,
#   'critical': 274,
#   'new_deaths': 0,
#   'total_tests': 58521,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2292'),
#   'total_deaths_per_million': Decimal('80'),
#   'population': Decimal('4034565')},
#  {'country': 'Ghana',
#   'confirmed': 9168,
#   'new_cases': 0,
#   'deaths': 42,
#   'recovered': 3457,
#   'active': 5669,
#   'critical': 3,
#   'new_deaths': 0,
#   'total_tests': 226741,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('296'),
#   'total_deaths_per_million': Decimal('1'),
#   'population': Decimal('31023387')},
#  {'country': 'Norway',
#   'confirmed': 8522,
#   'new_cases': 0,
#   'deaths': 238,
#   'recovered': 8138,
#   'active': 146,
#   'critical': 5,
#   'new_deaths': 0,
#   'total_tests': 257303,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1573'),
#   'total_deaths_per_million': Decimal('44'),
#   'population': Decimal('5418299')},
#  {'country': 'Malaysia',
#   'confirmed': 8266,
#   'new_cases': 0,
#   'deaths': 116,
#   'recovered': 6610,
#   'active': 1540,
#   'critical': 6,
#   'new_deaths': 0,
#   'total_tests': 560738,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('256'),
#   'total_deaths_per_million': Decimal('4'),
#   'population': Decimal('32336127')},
#  {'country': 'Morocco',
#   'confirmed': 8071,
#   'new_cases': 0,
#   'deaths': 208,
#   'recovered': 7268,
#   'active': 595,
#   'critical': 15,
#   'new_deaths': 0,
#   'total_tests': 275349,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('219'),
#   'total_deaths_per_million': Decimal('6'),
#   'population': Decimal('36879268')},
#  {'country': 'Cameroon',
#   'confirmed': 7392,
#   'new_cases': 0,
#   'deaths': 205,
#   'recovered': 4575,
#   'active': 2612,
#   'critical': 28,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('279'),
#   'total_deaths_per_million': Decimal('8'),
#   'population': Decimal('26493910')},
#  {'country': 'Australia',
#   'confirmed': 7255,
#   'new_cases': 4,
#   'deaths': 102,
#   'recovered': 6690,
#   'active': 463,
#   'critical': 2,
#   'new_deaths': 0,
#   'total_tests': 1603027,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('285'),
#   'total_deaths_per_million': Decimal('4'),
#   'population': Decimal('25478762')},
#  {'country': 'Finland',
#   'confirmed': 6941,
#   'new_cases': 0,
#   'deaths': 322,
#   'recovered': 5800,
#   'active': 819,
#   'critical': 8,
#   'new_deaths': 0,
#   'total_tests': 198647,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1253'),
#   'total_deaths_per_million': Decimal('58'),
#   'population': Decimal('5540151')},
#  {'country': 'Azerbaijan',
#   'confirmed': 6860,
#   'new_cases': 0,
#   'deaths': 82,
#   'recovered': 3871,
#   'active': 2907,
#   'critical': 66,
#   'new_deaths': 0,
#   'total_tests': 328385,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('677'),
#   'total_deaths_per_million': Decimal('8'),
#   'population': Decimal('10132778')},
#  {'country': 'Guatemala',
#   'confirmed': 6485,
#   'new_cases': 331,
#   'deaths': 216,
#   'recovered': 1053,
#   'active': 5216,
#   'critical': 5,
#   'new_deaths': 58,
#   'total_tests': 31427,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('362'),
#   'total_deaths_per_million': Decimal('12'),
#   'population': Decimal('17890679')},
#  {'country': 'Honduras',
#   'confirmed': 5971,
#   'new_cases': 91,
#   'deaths': 248,
#   'recovered': 677,
#   'active': 5046,
#   'critical': 13,
#   'new_deaths': 5,
#   'total_tests': 14790,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('604'),
#   'total_deaths_per_million': Decimal('25'),
#   'population': Decimal('9892998')},
#  {'country': 'Sudan',
#   'confirmed': 5865,
#   'new_cases': 0,
#   'deaths': 347,
#   'recovered': 1924,
#   'active': 3594,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 401,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('134'),
#   'total_deaths_per_million': Decimal('8'),
#   'population': Decimal('43769644')},
#  {'country': 'Tajikistan',
#   'confirmed': 4370,
#   'new_cases': 0,
#   'deaths': 48,
#   'recovered': 2491,
#   'active': 1831,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('459'),
#   'total_deaths_per_million': Decimal('5'),
#   'population': Decimal('9521091')},
#  {'country': 'Senegal',
#   'confirmed': 4155,
#   'new_cases': 0,
#   'deaths': 45,
#   'recovered': 2276,
#   'active': 1834,
#   'critical': 15,
#   'new_deaths': 0,
#   'total_tests': 49180,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('249'),
#   'total_deaths_per_million': Decimal('3'),
#   'population': Decimal('16708875')},
#  {'country': 'Djibouti',
#   'confirmed': 4123,
#   'new_cases': 0,
#   'deaths': 26,
#   'recovered': 1707,
#   'active': 2390,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 34551,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('4178'),
#   'total_deaths_per_million': Decimal('26'),
#   'population': Decimal('986952')},
#  {'country': 'Guinea',
#   'confirmed': 4060,
#   'new_cases': 0,
#   'deaths': 23,
#   'recovered': 2667,
#   'active': 1370,
#   'critical': 24,
#   'new_deaths': 0,
#   'total_tests': 14407,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('310'),
#   'total_deaths_per_million': Decimal('2'),
#   'population': Decimal('13104342')},
#  {'country': 'Luxembourg',
#   'confirmed': 4032,
#   'new_cases': 0,
#   'deaths': 110,
#   'recovered': 3885,
#   'active': 37,
#   'critical': 3,
#   'new_deaths': 0,
#   'total_tests': 83673,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('6449'),
#   'total_deaths_per_million': Decimal('176'),
#   'population': Decimal('625225')},
#  {'country': 'Uzbekistan',
#   'confirmed': 4022,
#   'new_cases': 15,
#   'deaths': 16,
#   'recovered': 3247,
#   'active': 759,
#   'critical': 13,
#   'new_deaths': 0,
#   'total_tests': 748555,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('120'),
#   'total_deaths_per_million': Decimal('0.5'),
#   'population': Decimal('33433825')},
#  {'country': 'Hungary',
#   'confirmed': 3990,
#   'new_cases': 20,
#   'deaths': 545,
#   'recovered': 2279,
#   'active': 1166,
#   'critical': 21,
#   'new_deaths': 3,
#   'total_tests': 206853,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('413'),
#   'total_deaths_per_million': Decimal('56'),
#   'population': Decimal('9661922')},
#  {'country': 'DRC',
#   'confirmed': 3764,
#   'new_cases': 0,
#   'deaths': 81,
#   'recovered': 512,
#   'active': 3171,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('42'),
#   'total_deaths_per_million': Decimal('0.9'),
#   'population': Decimal('89338858')},
#  {'country': 'Ivory Coast',
#   'confirmed': 3431,
#   'new_cases': 0,
#   'deaths': 36,
#   'recovered': 1604,
#   'active': 1791,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 29856,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('130'),
#   'total_deaths_per_million': Decimal('1'),
#   'population': Decimal('26326964')},
#  {'country': 'Thailand',
#   'confirmed': 3104,
#   'new_cases': 2,
#   'deaths': 58,
#   'recovered': 2971,
#   'active': 75,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 420529,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('44'),
#   'total_deaths_per_million': Decimal('0.8'),
#   'population': Decimal('69788308')},
#  {'country': 'Gabon',
#   'confirmed': 3101,
#   'new_cases': 0,
#   'deaths': 21,
#   'recovered': 833,
#   'active': 2247,
#   'critical': 13,
#   'new_deaths': 0,
#   'total_tests': 16730,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1396'),
#   'total_deaths_per_million': Decimal('9'),
#   'population': Decimal('2221643')},
#  {'country': 'Greece',
#   'confirmed': 2967,
#   'new_cases': 0,
#   'deaths': 180,
#   'recovered': 1374,
#   'active': 1413,
#   'critical': 9,
#   'new_deaths': 0,
#   'total_tests': 193929,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('285'),
#   'total_deaths_per_million': Decimal('17'),
#   'population': Decimal('10426255')},
#  {'country': 'Haiti',
#   'confirmed': 2924,
#   'new_cases': 184,
#   'deaths': 50,
#   'recovered': 24,
#   'active': 2850,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 6626,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('257'),
#   'total_deaths_per_million': Decimal('4'),
#   'population': Decimal('11392561')},
#  {'country': 'Nepal',
#   'confirmed': 2912,
#   'new_cases': 0,
#   'deaths': 11,
#   'recovered': 333,
#   'active': 2568,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 221332,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('100'),
#   'total_deaths_per_million': Decimal('0.4'),
#   'population': Decimal('29097598')},
#  {'country': 'El Salvador',
#   'confirmed': 2849,
#   'new_cases': 0,
#   'deaths': 53,
#   'recovered': 1249,
#   'active': 1547,
#   'critical': 58,
#   'new_deaths': 0,
#   'total_tests': 101604,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('439'),
#   'total_deaths_per_million': Decimal('8'),
#   'population': Decimal('6483981')},
#  {'country': 'North Macedonia',
#   'confirmed': 2790,
#   'new_cases': 0,
#   'deaths': 149,
#   'recovered': 1632,
#   'active': 1009,
#   'critical': 34,
#   'new_deaths': 0,
#   'total_tests': 33114,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1339'),
#   'total_deaths_per_million': Decimal('72'),
#   'population': Decimal('2083380')},
#  {'country': 'Bulgaria',
#   'confirmed': 2668,
#   'new_cases': 41,
#   'deaths': 160,
#   'recovered': 1528,
#   'active': 980,
#   'critical': 12,
#   'new_deaths': 1,
#   'total_tests': 89086,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('384'),
#   'total_deaths_per_million': Decimal('23'),
#   'population': Decimal('6951664')},
#  {'country': 'Bosnia and Herzegovina',
#   'confirmed': 2606,
#   'new_cases': 0,
#   'deaths': 159,
#   'recovered': 1968,
#   'active': 479,
#   'critical': 4,
#   'new_deaths': 0,
#   'total_tests': 69654,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('794'),
#   'total_deaths_per_million': Decimal('48'),
#   'population': Decimal('3282088')},
#  {'country': 'Kenya',
#   'confirmed': 2474,
#   'new_cases': 0,
#   'deaths': 79,
#   'recovered': 643,
#   'active': 1752,
#   'critical': 7,
#   'new_deaths': 0,
#   'total_tests': 90875,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('46'),
#   'total_deaths_per_million': Decimal('1'),
#   'population': Decimal('53680055')},
#  {'country': 'Croatia',
#   'confirmed': 2247,
#   'new_cases': 0,
#   'deaths': 103,
#   'recovered': 2113,
#   'active': 31,
#   'critical': 3,
#   'new_deaths': 0,
#   'total_tests': 68267,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('547'),
#   'total_deaths_per_million': Decimal('25'),
#   'population': Decimal('4106842')},
#  {'country': 'Somalia',
#   'confirmed': 2204,
#   'new_cases': 0,
#   'deaths': 79,
#   'recovered': 418,
#   'active': 1707,
#   'critical': 2,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('139'),
#   'total_deaths_per_million': Decimal('5'),
#   'population': Decimal('15857611')},
#  {'country': 'Venezuela',
#   'confirmed': 2145,
#   'new_cases': 0,
#   'deaths': 20,
#   'recovered': 334,
#   'active': 1791,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 1009524,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('75'),
#   'total_deaths_per_million': Decimal('0.7'),
#   'population': Decimal('28441089')},
#  {'country': 'Cuba',
#   'confirmed': 2133,
#   'new_cases': 0,
#   'deaths': 83,
#   'recovered': 1848,
#   'active': 202,
#   'critical': 3,
#   'new_deaths': 0,
#   'total_tests': 114464,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('188'),
#   'total_deaths_per_million': Decimal('7'),
#   'population': Decimal('11327066')},
#  {'country': 'Mayotte',
#   'confirmed': 2079,
#   'new_cases': 0,
#   'deaths': 25,
#   'recovered': 1523,
#   'active': 531,
#   'critical': 12,
#   'new_deaths': 0,
#   'total_tests': 8150,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('7635'),
#   'total_deaths_per_million': Decimal('92'),
#   'population': Decimal('272300')},
#  {'country': 'Kyrgyzstan',
#   'confirmed': 1974,
#   'new_cases': 38,
#   'deaths': 22,
#   'recovered': 1360,
#   'active': 592,
#   'critical': 5,
#   'new_deaths': 0,
#   'total_tests': 127051,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('303'),
#   'total_deaths_per_million': Decimal('3'),
#   'population': Decimal('6516228')},
#  {'country': 'Estonia',
#   'confirmed': 1931,
#   'new_cases': 21,
#   'deaths': 69,
#   'recovered': 1675,
#   'active': 187,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 89000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1456'),
#   'total_deaths_per_million': Decimal('52'),
#   'population': Decimal('1326476')},
#  {'country': 'Maldives',
#   'confirmed': 1883,
#   'new_cases': 0,
#   'deaths': 7,
#   'recovered': 717,
#   'active': 1159,
#   'critical': 9,
#   'new_deaths': 0,
#   'total_tests': 28440,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3488'),
#   'total_deaths_per_million': Decimal('13'),
#   'population': Decimal('539834')},
#  {'country': 'Iceland',
#   'confirmed': 1806,
#   'new_cases': 0,
#   'deaths': 10,
#   'recovered': 1794,
#   'active': 2,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 62230,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('5295'),
#   'total_deaths_per_million': Decimal('29'),
#   'population': Decimal('341091')},
#  {'country': 'Ethiopia',
#   'confirmed': 1805,
#   'new_cases': 0,
#   'deaths': 19,
#   'recovered': 262,
#   'active': 1524,
#   'critical': 18,
#   'new_deaths': 0,
#   'total_tests': 131368,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('16'),
#   'total_deaths_per_million': Decimal('0.2'),
#   'population': Decimal('114739889')},
#  {'country': 'Sri Lanka',
#   'confirmed': 1801,
#   'new_cases': 0,
#   'deaths': 11,
#   'recovered': 858,
#   'active': 932,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 73996,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('84'),
#   'total_deaths_per_million': Decimal('0.5'),
#   'population': Decimal('21407188')},
#  {'country': 'Lithuania',
#   'confirmed': 1694,
#   'new_cases': 0,
#   'deaths': 71,
#   'recovered': 1302,
#   'active': 321,
#   'critical': 17,
#   'new_deaths': 0,
#   'total_tests': 326294,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('622'),
#   'total_deaths_per_million': Decimal('26'),
#   'population': Decimal('2724507')},
#  {'country': 'Slovakia',
#   'confirmed': 1528,
#   'new_cases': 2,
#   'deaths': 28,
#   'recovered': 1379,
#   'active': 121,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 188235,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('280'),
#   'total_deaths_per_million': Decimal('5'),
#   'population': Decimal('5459469')},
#  {'country': 'New Zealand',
#   'confirmed': 1504,
#   'new_cases': 0,
#   'deaths': 22,
#   'recovered': 1481,
#   'active': 1,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 291194,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('301'),
#   'total_deaths_per_million': Decimal('4'),
#   'population': Decimal('5002100')},
#  {'country': 'Mali',
#   'confirmed': 1485,
#   'new_cases': 0,
#   'deaths': 87,
#   'recovered': 816,
#   'active': 582,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 3483,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('74'),
#   'total_deaths_per_million': Decimal('4'),
#   'population': Decimal('20203690')},
#  {'country': 'Slovenia',
#   'confirmed': 1479,
#   'new_cases': 0,
#   'deaths': 109,
#   'recovered': 1359,
#   'active': 11,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 83529,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('711'),
#   'total_deaths_per_million': Decimal('52'),
#   'population': Decimal('2078919')},
#  {'country': 'CAR',
#   'confirmed': 1451,
#   'new_cases': 0,
#   'deaths': 4,
#   'recovered': 29,
#   'active': 1418,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 15881,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('301'),
#   'total_deaths_per_million': Decimal('0.8'),
#   'population': Decimal('4823511')},
#  {'country': 'Guinea-Bissau',
#   'confirmed': 1368,
#   'new_cases': 0,
#   'deaths': 12,
#   'recovered': 153,
#   'active': 1203,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 1500,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('696'),
#   'total_deaths_per_million': Decimal('6'),
#   'population': Decimal('1964376')},
#  {'country': 'Lebanon',
#   'confirmed': 1312,
#   'new_cases': 0,
#   'deaths': 28,
#   'recovered': 768,
#   'active': 516,
#   'critical': 6,
#   'new_deaths': 0,
#   'total_tests': 92175,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('192'),
#   'total_deaths_per_million': Decimal('4'),
#   'population': Decimal('6827373')},
#  {'country': 'Equatorial Guinea',
#   'confirmed': 1306,
#   'new_cases': 0,
#   'deaths': 12,
#   'recovered': 200,
#   'active': 1094,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 8268,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('933'),
#   'total_deaths_per_million': Decimal('9'),
#   'population': Decimal('1399153')},
#  {'country': 'Costa Rica',
#   'confirmed': 1228,
#   'new_cases': 0,
#   'deaths': 10,
#   'recovered': 695,
#   'active': 523,
#   'critical': 4,
#   'new_deaths': 0,
#   'total_tests': 28753,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('241'),
#   'total_deaths_per_million': Decimal('2'),
#   'population': Decimal('5090858')},
#  {'country': 'Albania',
#   'confirmed': 1212,
#   'new_cases': 0,
#   'deaths': 33,
#   'recovered': 910,
#   'active': 269,
#   'critical': 5,
#   'new_deaths': 0,
#   'total_tests': 15810,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('421'),
#   'total_deaths_per_million': Decimal('11'),
#   'population': Decimal('2878001')},
#  {'country': 'Nicaragua',
#   'confirmed': 1118,
#   'new_cases': 0,
#   'deaths': 46,
#   'recovered': 370,
#   'active': 702,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('169'),
#   'total_deaths_per_million': Decimal('7'),
#   'population': Decimal('6618915')},
#  {'country': 'Hong Kong',
#   'confirmed': 1103,
#   'new_cases': 0,
#   'deaths': 4,
#   'recovered': 1045,
#   'active': 54,
#   'critical': 2,
#   'new_deaths': 0,
#   'total_tests': 202930,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('147'),
#   'total_deaths_per_million': Decimal('0.5'),
#   'population': Decimal('7492751')},
#  {'country': 'Zambia',
#   'confirmed': 1089,
#   'new_cases': 0,
#   'deaths': 7,
#   'recovered': 912,
#   'active': 170,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 28236,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('59'),
#   'total_deaths_per_million': Decimal('0.4'),
#   'population': Decimal('18342575')},
#  {'country': 'Tunisia',
#   'confirmed': 1087,
#   'new_cases': 0,
#   'deaths': 49,
#   'recovered': 969,
#   'active': 69,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 54150,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('92'),
#   'total_deaths_per_million': Decimal('4'),
#   'population': Decimal('11809865')},
#  {'country': 'Paraguay',
#   'confirmed': 1087,
#   'new_cases': 0,
#   'deaths': 11,
#   'recovered': 516,
#   'active': 560,
#   'critical': 2,
#   'new_deaths': 0,
#   'total_tests': 35258,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('153'),
#   'total_deaths_per_million': Decimal('2'),
#   'population': Decimal('7126251')},
#  {'country': 'Latvia',
#   'confirmed': 1086,
#   'new_cases': 1,
#   'deaths': 25,
#   'recovered': 781,
#   'active': 280,
#   'critical': 3,
#   'new_deaths': 0,
#   'total_tests': 116535,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('575'),
#   'total_deaths_per_million': Decimal('13'),
#   'population': Decimal('1887445')},
#  {'country': 'South Sudan',
#   'confirmed': 994,
#   'new_cases': 0,
#   'deaths': 10,
#   'recovered': 6,
#   'active': 978,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 3356,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('89'),
#   'total_deaths_per_million': Decimal('0.9'),
#   'population': Decimal('11184347')},
#  {'country': 'Madagascar',
#   'confirmed': 975,
#   'new_cases': 0,
#   'deaths': 7,
#   'recovered': 201,
#   'active': 767,
#   'critical': 9,
#   'new_deaths': 0,
#   'total_tests': 12907,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('35'),
#   'total_deaths_per_million': Decimal('0.3'),
#   'population': Decimal('27634723')},
#  {'country': 'Niger',
#   'confirmed': 966,
#   'new_cases': 0,
#   'deaths': 65,
#   'recovered': 863,
#   'active': 38,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 6119,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('40'),
#   'total_deaths_per_million': Decimal('3'),
#   'population': Decimal('24132092')},
#  {'country': 'Cyprus',
#   'confirmed': 960,
#   'new_cases': 0,
#   'deaths': 17,
#   'recovered': 807,
#   'active': 136,
#   'critical': 4,
#   'new_deaths': 0,
#   'total_tests': 125312,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('796'),
#   'total_deaths_per_million': Decimal('14'),
#   'population': Decimal('1206752')},
#  {'country': 'Sierra Leone',
#   'confirmed': 929,
#   'new_cases': 0,
#   'deaths': 47,
#   'recovered': 580,
#   'active': 302,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('117'),
#   'total_deaths_per_million': Decimal('6'),
#   'population': Decimal('7964638')},
#  {'country': 'Burkina Faso',
#   'confirmed': 888,
#   'new_cases': 0,
#   'deaths': 53,
#   'recovered': 760,
#   'active': 75,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('43'),
#   'total_deaths_per_million': Decimal('3'),
#   'population': Decimal('20857394')},
#  {'country': 'Mauritania',
#   'confirmed': 883,
#   'new_cases': 0,
#   'deaths': 43,
#   'recovered': 69,
#   'active': 771,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 7654,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('190'),
#   'total_deaths_per_million': Decimal('9'),
#   'population': Decimal('4639954')},
#  {'country': 'Andorra',
#   'confirmed': 852,
#   'new_cases': 0,
#   'deaths': 51,
#   'recovered': 741,
#   'active': 60,
#   'critical': 7,
#   'new_deaths': 0,
#   'total_tests': 3750,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('11028'),
#   'total_deaths_per_million': Decimal('660'),
#   'population': Decimal('77257')},
#  {'country': 'Chad',
#   'confirmed': 836,
#   'new_cases': 0,
#   'deaths': 68,
#   'recovered': 657,
#   'active': 111,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('51'),
#   'total_deaths_per_million': Decimal('4'),
#   'population': Decimal('16387798')},
#  {'country': 'Uruguay',
#   'confirmed': 834,
#   'new_cases': 0,
#   'deaths': 23,
#   'recovered': 721,
#   'active': 90,
#   'critical': 4,
#   'new_deaths': 0,
#   'total_tests': 47433,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('240'),
#   'total_deaths_per_million': Decimal('7'),
#   'population': Decimal('3472922')},
#  {'country': 'Georgia',
#   'confirmed': 808,
#   'new_cases': 3,
#   'deaths': 13,
#   'recovered': 663,
#   'active': 132,
#   'critical': 6,
#   'new_deaths': 0,
#   'total_tests': 61395,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('203'),
#   'total_deaths_per_million': Decimal('3'),
#   'population': Decimal('3989660')},
#  {'country': 'Jordan',
#   'confirmed': 784,
#   'new_cases': 0,
#   'deaths': 9,
#   'recovered': 571,
#   'active': 204,
#   'critical': 5,
#   'new_deaths': 0,
#   'total_tests': 213815,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('77'),
#   'total_deaths_per_million': Decimal('0.9'),
#   'population': Decimal('10195993')},
#  {'country': 'Diamond Princess',
#   'confirmed': 712,
#   'new_cases': 0,
#   'deaths': 13,
#   'recovered': 651,
#   'active': 48,
#   'critical': 4,
#   'new_deaths': 0,
# ...
#  {'country': 'Syria',
#   'confirmed': 124,
#   'new_cases': 0,
#   'deaths': 6,
#   'recovered': 53,
#   'active': 65,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('7'),
#   'total_deaths_per_million': Decimal('0.3'),
#   'population': Decimal('17467375')},
#  {'country': 'Trinidad and Tobago',
#   'confirmed': 117,
#   'new_cases': 0,
#   'deaths': 8,
#   'recovered': 108,
#   'active': 1,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 3325,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('84'),
#   'total_deaths_per_million': Decimal('6'),
#   'population': Decimal('1399184')},
#  {'country': 'Bahamas',
#   'confirmed': 102,
#   'new_cases': 0,
#   'deaths': 11,
#   'recovered': 55,
#   'active': 36,
#   'critical': 2,
#   'new_deaths': 0,
#   'total_tests': 2156,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('260'),
#   'total_deaths_per_million': Decimal('28'),
#   'population': Decimal('392980')},
#  {'country': 'Aruba',
#   'confirmed': 101,
#   'new_cases': 0,
#   'deaths': 3,
#   'recovered': 98,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 2168,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('946'),
#   'total_deaths_per_million': Decimal('28'),
#   'population': Decimal('106735')},
#  {'country': 'Monaco',
#   'confirmed': 99,
#   'new_cases': 0,
#   'deaths': 4,
#   'recovered': 93,
#   'active': 2,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 16200,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2524'),
#   'total_deaths_per_million': Decimal('102'),
#   'population': Decimal('39223')},
#  {'country': 'Barbados',
#   'confirmed': 92,
#   'new_cases': 0,
#   'deaths': 7,
#   'recovered': 81,
#   'active': 4,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 5812,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('320'),
#   'total_deaths_per_million': Decimal('24'),
#   'population': Decimal('287352')},
#  {'country': 'Suriname',
#   'confirmed': 91,
#   'new_cases': 1,
#   'deaths': 1,
#   'recovered': 9,
#   'active': 81,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 782,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('155'),
#   'total_deaths_per_million': Decimal('2'),
#   'population': Decimal('586264')},
#  {'country': 'Angola',
#   'confirmed': 86,
#   'new_cases': 0,
#   'deaths': 4,
#   'recovered': 21,
#   'active': 61,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 10000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3'),
#   'total_deaths_per_million': Decimal('0.1'),
#   'population': Decimal('32782300')},
#  {'country': 'Liechtenstein',
#   'confirmed': 82,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 55,
#   'active': 26,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 900,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2151'),
#   'total_deaths_per_million': Decimal('26'),
#   'population': Decimal('38121')},
#  {'country': 'Sint Maarten',
#   'confirmed': 77,
#   'new_cases': 0,
#   'deaths': 15,
#   'recovered': 61,
#   'active': 1,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 470,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1797'),
#   'total_deaths_per_million': Decimal('350'),
#   'population': Decimal('42841')},
#  {'country': 'Burundi',
#   'confirmed': 63,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 33,
#   'active': 29,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 284,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('5'),
#   'total_deaths_per_million': Decimal('0.08'),
#   'population': Decimal('11861964')},
#  {'country': 'French Polynesia',
#   'confirmed': 60,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 60,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 4040,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('214'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('280797')},
#  {'country': 'Bhutan',
#   'confirmed': 48,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 11,
#   'active': 37,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 19004,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('62'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('771004')},
#  {'country': 'Macao',
#   'confirmed': 45,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 45,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('69'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('648693')},
#  {'country': 'Saint Martin',
#   'confirmed': 41,
#   'new_cases': 0,
#   'deaths': 3,
#   'recovered': 33,
#   'active': 5,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 614,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1062'),
#   'total_deaths_per_million': Decimal('78'),
#   'population': Decimal('38617')},
#  {'country': 'Botswana',
#   'confirmed': 40,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 23,
#   'active': 16,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 24006,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('17'),
#   'total_deaths_per_million': Decimal('0.4'),
#   'population': Decimal('2348017')},
#  {'country': 'Eritrea',
#   'confirmed': 39,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 39,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('11'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('3542858')},
#  {'country': 'Antigua and Barbuda',
#   'confirmed': 26,
#   'new_cases': 0,
#   'deaths': 3,
#   'recovered': 20,
#   'active': 3,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 246,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('266'),
#   'total_deaths_per_million': Decimal('31'),
#   'population': Decimal('97873')},
#  {'country': 'Gambia',
#   'confirmed': 26,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 21,
#   'active': 4,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 1907,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('11'),
#   'total_deaths_per_million': Decimal('0.4'),
#   'population': Decimal('2411208')},
#  {'country': 'St. Vincent Grenadines',
#   'confirmed': 26,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 15,
#   'active': 11,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 600,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('234'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('110916')},
#  {'country': 'Namibia',
#   'confirmed': 25,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 16,
#   'active': 9,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 4395,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('10'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('2537459')},
#  {'country': 'Timor-Leste',
#   'confirmed': 24,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 24,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 1568,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('18'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('1316552')},
#  {'country': 'Grenada',
#   'confirmed': 23,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 22,
#   'active': 1,
#   'critical': 2,
#   'new_deaths': 0,
#   'total_tests': 3516,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('204'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('112488')},
#  {'country': 'Curaçao',
#   'confirmed': 21,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 15,
#   'active': 5,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 985,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('128'),
#   'total_deaths_per_million': Decimal('6'),
#   'population': Decimal('164048')},
#  {'country': 'New Caledonia',
#   'confirmed': 20,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 18,
#   'active': 2,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 7055,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('70'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('285305')},
#  {'country': 'Belize',
#   'confirmed': 19,
#   'new_cases': 0,
#   'deaths': 2,
#   'recovered': 16,
#   'active': 1,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 1741,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('48'),
#   'total_deaths_per_million': Decimal('5'),
#   'population': Decimal('397087')},
#  {'country': 'Laos',
#   'confirmed': 19,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 18,
#   'active': 1,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 7824,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('7267859')},
#  {'country': 'Saint Lucia',
#   'confirmed': 19,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 18,
#   'active': 1,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 1204,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('104'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('183570')},
#  {'country': 'Dominica',
#   'confirmed': 18,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 16,
#   'active': 2,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 534,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('250'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('71974')},
#  {'country': 'Fiji',
#   'confirmed': 18,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 18,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 2431,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('20'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('895996')},
#  {'country': 'Saint Kitts and Nevis',
#   'confirmed': 15,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 15,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 403,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('282'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('53173')},
#  {'country': 'Falkland Islands',
#   'confirmed': 13,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 13,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 535,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3744'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('3472')},
#  {'country': 'Greenland',
#   'confirmed': 13,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 13,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 2288,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('229'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('56763')},
#  {'country': 'Turks and Caicos',
#   'confirmed': 12,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 11,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 153,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('310'),
#   'total_deaths_per_million': Decimal('26'),
#   'population': Decimal('38679')},
#  {'country': 'Vatican City',
#   'confirmed': 12,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 2,
#   'active': 10,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('14981'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('801')},
#  {'country': 'Montserrat',
#   'confirmed': 11,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 10,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 61,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2204'),
#   'total_deaths_per_million': Decimal('200'),
#   'population': Decimal('4992')},
#  {'country': 'Seychelles',
#   'confirmed': 11,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 11,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('112'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('98305')},
#  {'country': 'MS Zaandam',
#   'confirmed': 9,
#   'new_cases': 0,
#   'deaths': 2,
#   'recovered': 0,
#   'active': 7,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'Western Sahara',
#   'confirmed': 9,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 6,
#   'active': 2,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('15'),
#   'total_deaths_per_million': Decimal('2'),
#   'population': Decimal('596187')},
#  {'country': 'British Virgin Islands',
#   'confirmed': 8,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 7,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 167,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('265'),
#   'total_deaths_per_million': Decimal('33'),
#   'population': Decimal('30217')},
#  {'country': 'Papua New Guinea',
#   'confirmed': 8,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 8,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 4646,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0.9'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('8934255')},
#  {'country': 'Caribbean Netherlands',
#   'confirmed': 7,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 7,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 424,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('267'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('26206')},
#  {'country': 'St. Barth',
#   'confirmed': 6,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 6,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 137,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('608'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('9875')},
#  {'country': 'Lesotho',
#   'confirmed': 4,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 2,
#   'active': 2,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 1515,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('2141070')},
#  {'country': 'Anguilla',
#   'confirmed': 3,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 3,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 41,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('200'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('14994')},
#  {'country': 'Saint Pierre Miquelon',
#   'confirmed': 1,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 1,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('173'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('5796')},
#  {'country': 'China',
#   'confirmed': 83030,
#   'new_cases': 3,
#   'deaths': 4634,
#   'recovered': 78329,
#   'active': 67,
#   'critical': 2,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('58'),
#   'total_deaths_per_million': Decimal('3'),
#   'population': Decimal('1439323776')}]

# %%
x = 'a,b,c'

x.count(',')
# Out:
# 2

# %%
m = 'abc'
n = 'abc'

id(m)==id(n)
# Out:
# True

# %%
id(m)
# Out:
# 2354297126832

# %%
a = int(10)
b = int('10')
c = int('1010',2)
print(a)
# Out:
# 10

# %%
type(a)
# Out:
# int

# %%
import math
math.floor(-3.0000000000000001)
# Out:
# -3

# %%
math.floor(-3.000000000000001)
# Out:
# -4

# %%
a=0.1
b = 0.4
c=0.3
d = b -c
print(a==d)
# Out:
# False

# %%
print(d)
# Out:
# 0.10000000000000003

# %%
a,*b,(c,*d)= [1,2,3,'python']

# %%
a
# Out:
# 1

# %%
b
# Out:
# [2, 3]

# %%
c
# Out:
# 'p'

# %%
d
# Out:
# ['y', 't', 'h', 'o', 'n']

# %%
result = [str(number)+direction for number, direction in zip(range(1, 11), 'NSWE'*3)]
print(result[3])
#This prints?
# Out:
# 4E
