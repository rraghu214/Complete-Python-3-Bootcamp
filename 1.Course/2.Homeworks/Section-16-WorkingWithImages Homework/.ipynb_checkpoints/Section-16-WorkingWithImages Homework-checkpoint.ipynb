# %% [markdown]
# # Reveal the secret message by merging the Images

# %%
from PIL import Image

# %%
word_matrix = Image.open('word_matrix.png')

# %%
word_matrix
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x1A859A4F208>

# %%
mask = Image.open('mask.png')

# %%
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=505x251 at 0x1A859AE1E08>

# %%
word_matrix.size
# Out:
# (1015, 559)

# %%
mask.size
# Out:
# (505, 251)

# %%
mask.putalpha(50)

# %%
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=505x251 at 0x1A859AE1E08>

# %%
word_matrix.paste(im=mask.resize((1015,559)),box = (0,0),mask = mask.resize((1015,559)))

# %%
word_matrix
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x1A859A4F208>
