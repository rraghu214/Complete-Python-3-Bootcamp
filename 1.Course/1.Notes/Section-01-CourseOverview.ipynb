# %% [markdown]
# ### What can you do with Python?
# - Automate Simple tasks
#     - Searching for files and editing them.
#     - Scraping information from a website.
#     - Reading and editing excel files.
#     - Work with PDFs.
#     - Automate emails and text messages.
#     - Fill out forms
# - Data Science and Machine Learning
#     - Analyze large data files using - Numpy, Pandas
#     - Create visualizations using - cborn, matplotlib
#     - Perform ML tasks
#     - Create and run predicitve algorithms - SciKitLearn, Tensorflow
# - Create Websites
#     - Use Webframeworks such as django and flask to handle the backend of a website and user data.
#     - Create interactive dasboards for users using Plotly & DASH

# %% [markdown]
# 15	Iterables and Iterators	Iterating Collections
# 		Iterators
# 		Iterables
# 		Cyclic Iterators
# 		in-built Iterators
# 		iter() function and iterator applications
# ![image.png](attachment:image.png)

# %% [markdown]
# LaTex: a2
