# %% [markdown]
# # Errors & Exception Handling
#
# - try
# - except
# - finally
# - else --> used when NO exeption
#
# - Handling it in a while loop
# - Catching specific errors only

# %% [markdown]
# # Pylint Overview
#
# - Unit testing ensures the code base updated doesn't break your code by running unit tests.
# #### pylint
# - Looks at the code and reports back possible issues. Styling issues / invalid code
# #### unittest
# - Built in program to test your own programs and check you are getting desired outputs.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Fixed all the feedbacks.
# - Made the file name as snake case. --> testing_pylint.py
# - Changed the variable names to num_1 & num_2, it still gave that error. Changed it to NUM_1 & NUM_2. Then it resolved.
# - Added doc string.
# - Added a new line at last.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Running All the tests with Unit test Library
#
# To show this,
# - A simple script that capitalizes the text.
# - Actual test script.
# - We need to build a test class.

# %% [markdown]
# ![image.png](attachment:image.png)
